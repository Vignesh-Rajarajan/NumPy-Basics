# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ppoints=np.arange(-1,1,.01)

# %%
ppoints
# Out:
# array([ -1.00000000e+00,  -9.90000000e-01,  -9.80000000e-01,
#         -9.70000000e-01,  -9.60000000e-01,  -9.50000000e-01,
#         -9.40000000e-01,  -9.30000000e-01,  -9.20000000e-01,
#         -9.10000000e-01,  -9.00000000e-01,  -8.90000000e-01,
#         -8.80000000e-01,  -8.70000000e-01,  -8.60000000e-01,
#         -8.50000000e-01,  -8.40000000e-01,  -8.30000000e-01,
#         -8.20000000e-01,  -8.10000000e-01,  -8.00000000e-01,
#         -7.90000000e-01,  -7.80000000e-01,  -7.70000000e-01,
#         -7.60000000e-01,  -7.50000000e-01,  -7.40000000e-01,
#         -7.30000000e-01,  -7.20000000e-01,  -7.10000000e-01,
#         -7.00000000e-01,  -6.90000000e-01,  -6.80000000e-01,
#         -6.70000000e-01,  -6.60000000e-01,  -6.50000000e-01,
#         -6.40000000e-01,  -6.30000000e-01,  -6.20000000e-01,
#         -6.10000000e-01,  -6.00000000e-01,  -5.90000000e-01,
#         -5.80000000e-01,  -5.70000000e-01,  -5.60000000e-01,
# ...

# %%
point=np.arange(-1,1,.1)
point
# Out:
# array([ -1.00000000e+00,  -9.00000000e-01,  -8.00000000e-01,
#         -7.00000000e-01,  -6.00000000e-01,  -5.00000000e-01,
#         -4.00000000e-01,  -3.00000000e-01,  -2.00000000e-01,
#         -1.00000000e-01,  -2.22044605e-16,   1.00000000e-01,
#          2.00000000e-01,   3.00000000e-01,   4.00000000e-01,
#          5.00000000e-01,   6.00000000e-01,   7.00000000e-01,
#          8.00000000e-01,   9.00000000e-01])

# %%
graphPoints=np.arange(-5,5,0.01)
graphPoints
# Out:
# array([ -5.00000000e+00,  -4.99000000e+00,  -4.98000000e+00,
#         -4.97000000e+00,  -4.96000000e+00,  -4.95000000e+00,
#         -4.94000000e+00,  -4.93000000e+00,  -4.92000000e+00,
#         -4.91000000e+00,  -4.90000000e+00,  -4.89000000e+00,
#         -4.88000000e+00,  -4.87000000e+00,  -4.86000000e+00,
#         -4.85000000e+00,  -4.84000000e+00,  -4.83000000e+00,
#         -4.82000000e+00,  -4.81000000e+00,  -4.80000000e+00,
#         -4.79000000e+00,  -4.78000000e+00,  -4.77000000e+00,
#         -4.76000000e+00,  -4.75000000e+00,  -4.74000000e+00,
#         -4.73000000e+00,  -4.72000000e+00,  -4.71000000e+00,
#         -4.70000000e+00,  -4.69000000e+00,  -4.68000000e+00,
#         -4.67000000e+00,  -4.66000000e+00,  -4.65000000e+00,
#         -4.64000000e+00,  -4.63000000e+00,  -4.62000000e+00,
#         -4.61000000e+00,  -4.60000000e+00,  -4.59000000e+00,
#         -4.58000000e+00,  -4.57000000e+00,  -4.56000000e+00,
# ...

# %%
dx,dy=np.meshgrid(graphPoints,graphPoints)

# %%
z=(np.sin(dx)+ np.sin(dy))
z
# Out:
# array([[  1.91784855e+00,   1.92063718e+00,   1.92332964e+00, ...,
#          -8.07710558e-03,  -5.48108704e-03,  -2.78862876e-03],
#        [  1.92063718e+00,   1.92342581e+00,   1.92611827e+00, ...,
#          -5.28847682e-03,  -2.69245827e-03,  -5.85087534e-14],
#        [  1.92332964e+00,   1.92611827e+00,   1.92881072e+00, ...,
#          -2.59601854e-03,  -5.63993297e-14,   2.69245827e-03],
#        ...,
#        [ -8.07710558e-03,  -5.28847682e-03,  -2.59601854e-03, ...,
#          -1.93400276e+00,  -1.93140674e+00,  -1.92871428e+00],
#        [ -5.48108704e-03,  -2.69245827e-03,  -5.63993297e-14, ...,
#          -1.93140674e+00,  -1.92881072e+00,  -1.92611827e+00],
#        [ -2.78862876e-03,  -5.85087534e-14,   2.69245827e-03, ...,
#          -1.92871428e+00,  -1.92611827e+00,  -1.92342581e+00]])

# %%
plt.imshow(z)

# %%
plt.imshow()
plt.colorbar()
plt.tilte('plot for sin(x) + sin(y)')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-761ed3def690> in <module>()
# ----> 1 plt.imshow()
#       2 plt.colorbar()
#       3 plt.tilte('plot for sin(x) + sin(y)')
#
# TypeError: imshow() missing 1 required positional argument: 'X'

# %%
plt.imshow(z)
plt.colorbar()
plt.title('plot for sin(x) + sin(y)')

# %%
A2=np.arange(5)
B2=np.arange(0,500,100)
B2
# Out:
# array([  0, 100, 200, 300, 400])

# %%
condition=np.array([True,True,False,False,True,True])

# %%
answer=[(A_val if cond else B_val)for A_val,B_val,cond in zip(A2,B2,condition)]
answer
# Out:
# [0, 1, 200, 300, 4]

# %%
answer1=np.where(condition,A2,B2)
answer1
# Out:
# array([  0,   1, 200, 300,   4])

# %%
answer2=np.where(condition,A2,B2)
answer2
### need to have arrays of same size
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-27a11cc8b193> in <module>()
# ----> 1 answer2=np.where(condition,A2,B2)
#       2 answer2
#
# ValueError: operands could not be broadcast together with shapes (6,) (5,) (5,)

# %%
from numpy.random import randn

# %%
arr=randn(5,5)
arr
# Out:
# array([[-0.12885725,  1.7560715 , -0.75443618,  1.42661478,  0.59701658],
#        [ 0.02825538,  0.17265363, -0.37812698,  0.38977317, -1.1336337 ],
#        [ 0.19904616, -0.42859434, -0.68940725, -0.82116306,  0.69128366],
#        [ 0.55605755,  1.60133222,  0.72578305,  0.60922077,  0.10779763],
#        [ 0.44080369, -0.26397353,  0.91383815, -0.11661173, -0.20875829]])

# %%
np.where(arr>0,0,arr)
# Out:
# array([[-0.12885725,  0.        , -0.75443618,  0.        ,  0.        ],
#        [ 0.        ,  0.        , -0.37812698,  0.        , -1.1336337 ],
#        [ 0.        , -0.42859434, -0.68940725, -0.82116306,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,  0.        ,  0.        ],
#        [ 0.        , -0.26397353,  0.        , -0.11661173, -0.20875829]])

# %%
arrays=randn(19)
arrays
# Out:
# array([-0.85884513, -0.40006153, -1.29930383, -0.33283037, -1.41247618,
#        -0.56943122, -0.53223932, -1.16109651, -0.99388634,  0.5629243 ,
#        -2.07100913, -0.68286333,  2.00836476,  1.69945392, -0.16669021,
#         1.82785597,  1.2719438 , -0.98802654,  2.00696997])

# %%
arrays.sort()

# %%
arrays
# Out:
# array([-2.07100913, -1.41247618, -1.29930383, -1.16109651, -0.99388634,
#        -0.98802654, -0.85884513, -0.68286333, -0.56943122, -0.53223932,
#        -0.40006153, -0.33283037, -0.16669021,  0.5629243 ,  1.2719438 ,
#         1.69945392,  1.82785597,  2.00696997,  2.00836476])

# %%
states=np.array(['Tn','MP','MH','AS','AS','TN','PB','UJ','KL','AM','KJ'])
np.unique(states)
# Out:
# array(['AM', 'AS', 'KJ', 'KL', 'MH', 'MP', 'PB', 'TN', 'Tn', 'UJ'],
#       dtype='<U2')
